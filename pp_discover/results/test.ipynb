# %%
import imagehash
from PIL import Image

# %%
# Default phash
image = Image.open("/mnt/lts/nis_lab_research/pp_pkg/results/wd/cons_raw_img/pp_crawler/1730518159823_f70adb5e1194f1fa3fe39bf246bb1d96_FIRST_1920x1080.png")
default_phash = imagehash.phash(image)  # Resizes to 32x32 internally
print(default_phash)
# Out:
# e5646c9a9a939a69

# %%
# Custom resizing for higher resolution
custom_phash = imagehash.phash(image, hash_size=32 * 4)  # Resizes to 64x64
print(len(custom_phash))
# Out:
# 16384
